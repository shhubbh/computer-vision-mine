# %% [markdown]
# # To generate cropped tiff from big Tiff and Geojson
# ### Virtual Environment: remote_sensing_v2

# %%
import os
os.chdir('/home/GIS_WS/GIS_Roads_WS')

# %%
home_direc = os.getcwd()
print(home_direc)
# Out:
# /home/GIS_WS/GIS_Roads_WS

# %% [markdown]
# ##### Dictionaries for Cropping the tiff and geojson
# ### Check for the cropping size and overlap rate

# %%
# crop and convert the geojson and tiff file to coco format dataset

import os
import rasterio
from osgeo import gdal
import numpy as np
from tqdm.auto import tqdm, trange
import geopandas as gpd
from osgeo import ogr
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import cv2

# Save the raster image
def writeTiff(im_data, save_path, new_transform, crs):
    _, height, width = im_data.shape
    with rasterio.open(save_path,
                       'w',
                       driver='GTiff',
                       height=height,
                       width=width,
                       count=3,
                       dtype=im_data.dtype,
                       crs=crs,
                       transform=new_transform
                       ) as dst:
        dst.write(im_data)
    return

# read the raster image
def readTiff(TifPath):
    dataset_img = rasterio.open(TifPath)
    width = dataset_img.width
    height = dataset_img.height
    crs = dataset_img.crs
    transform = dataset_img.transform # (xres, 0, xcord, 0, yres, ycord)
    img_array = dataset_img.read([1, 2, 3]) # get the data
    return img_array, width, height, crs, transform

# Crop tiff image by sliding window method
def crop_tif(img_path, save_dir, stride=640, overlap_rate=0.20):
    # Side length of the overlapping area
    step = int(stride * overlap_rate)
    im_data, width, height, crs, transform = readTiff(img_path)
    im_name, _ = os.path.splitext(os.path.split(img_path)[-1])
    x_res = transform[0]
    y_res = transform[4]
    x_cord = transform[2]
    y_cord = transform[5]
    # Calculate the coordinates of the cropped image vertices for each row and column
    w_step = [i for i in range(0, width - stride, stride - step)]
    w_step.append(width - stride)
    h_step = [i for i in range(0, height - stride, stride - step)]
    h_step.append(height - stride)
    
    for i in trange(len(h_step)): # Crop row
        for j in range(len(w_step)): # Crop column
            cropped = im_data[:, h_step[i] : h_step[i] + stride, w_step[j] : w_step[j] + stride]
            # Calculate coordinate
            new_x_cord = x_cord + w_step[j] * x_res  
            new_y_cord = y_cord + h_step[i] * y_res  
            new_transform = (x_res, transform[1], new_x_cord, transform[3], y_res, new_y_cord)
            # save the image
            save_name = '{}_{}_{}.tif'.format(im_name, i, j) # Name of top left figure is 0_0.tif
            writeTiff(cropped, os.path.join(save_dir, save_name), new_transform, crs)
    print('Cropping TIFF finished!')


# crop the geojson acoording to the extent of geotiff
def crop_geojson(geojson_path, tif_dir, save_dir):
    # read geojson
    annot_df = gpd.read_file(geojson_path)
    # get the list of tiff files
    tif_list = [x for x in os.listdir(tif_dir) if x.endswith('tif')]
    tif_list.sort()
    for tif in tqdm(tif_list):
        tif_path = os.path.join(tif_dir, tif)
        # read tif and get the extent
        img_dataset = rasterio.open(tif_path)
        img_name = os.path.splitext(os.path.split(tif_path)[-1])[0]
        left, bottom, right, top = img_dataset.bounds
        # create mask in geopandas (minx, miny, maxx, maxy)
        mask = gpd.GeoSeries(Polygon([(left, bottom), (left, top), (right, top), (right, bottom)]), crs = annot_df.crs)
        mask_clip = gpd.clip(annot_df, mask)
        # Save geojson if cropped data is not empty
        if mask_clip.shape[0] != 0:
            # save path
            save_path = os.path.join(save_dir, img_name + '.geojson')
            mask_clip.to_file(save_path, driver= 'GeoJSON')
    print('Cropping GEOJSON finished!')

# translate Gdal data to opencv format
def GdalData2OpencvData(GdalImg_data):
    OpencvImg_data = np.zeros((GdalImg_data.shape[1],GdalImg_data.shape[2],GdalImg_data.shape[0]),np.uint8)
    for i in range(GdalImg_data.shape[0]):
        OpencvImg_data[:,:,i] = GdalImg_data[GdalImg_data.shape[0]-i-1,:,:]
    return OpencvImg_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 import os
#       4 import rasterio
# ----> 5 from osgeo import gdal
#       6 import numpy as np
#       7 from tqdm.auto import tqdm, trange
#
# ModuleNotFoundError: No module named 'osgeo'

# %% [markdown]
# ##### Cropping the TIFF image to small patches

# %%
# crop the tiff and geojson to patches

#root_direc = 'scene_classification_ws'  # path of root diretory
tif_path = os.path.join(home_direc, 'ortho.tif') # path of tiff images
save_crop_tiff_dir = os.path.join(home_direc,  'cropped_tiff')  # path to cropped geojson and tiff files
os.makedirs(save_crop_tiff_dir, exist_ok=True)

# crop the tif to size of 1024*1024, if you need
crop_tif(tif_path, save_crop_tiff_dir)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# Cropping TIFF finished!

# %%
from PIL import Image
import os

# Path to the folder containing TIFF images
tiff_folder = 'cropped_tiff'

# Path to the folder where you want to save the converted JPG images
jpg_folder = 'cropped_jpg'

# Create the output folder if it doesn't exist
os.makedirs(jpg_folder, exist_ok=True)

# Iterate through all TIFF files in the folder
for filename in os.listdir(tiff_folder):
    if filename.endswith('.tif') or filename.endswith('.tiff'):
        # Full path to the input TIFF file
        tiff_path = os.path.join(tiff_folder, filename)

        # Output path for the converted JPG file
        jpg_path = os.path.join(jpg_folder, os.path.splitext(filename)[0] + '.jpg')

        # Open the TIFF image
        tiff_image = Image.open(tiff_path)

        # Save the TIFF image as a JPG image
        tiff_image.save(jpg_path, 'JPEG')

        print(f"Conversion complete: {filename} -> {os.path.basename(jpg_path)}")
# Out:
# Conversion complete: ortho_11_9.tif -> ortho_11_9.jpg
# Conversion complete: ortho_16_22.tif -> ortho_16_22.jpg
# Conversion complete: ortho_2_12.tif -> ortho_2_12.jpg
# Conversion complete: ortho_24_14.tif -> ortho_24_14.jpg
# Conversion complete: ortho_19_12.tif -> ortho_19_12.jpg
# Conversion complete: ortho_23_19.tif -> ortho_23_19.jpg
# Conversion complete: ortho_5_21.tif -> ortho_5_21.jpg
# Conversion complete: ortho_14_22.tif -> ortho_14_22.jpg
# Conversion complete: ortho_9_23.tif -> ortho_9_23.jpg
# Conversion complete: ortho_0_13.tif -> ortho_0_13.jpg
# Conversion complete: ortho_0_23.tif -> ortho_0_23.jpg
# Conversion complete: ortho_21_1.tif -> ortho_21_1.jpg
# Conversion complete: ortho_7_23.tif -> ortho_7_23.jpg
# Conversion complete: ortho_7_8.tif -> ortho_7_8.jpg
# Conversion complete: ortho_1_23.tif -> ortho_1_23.jpg
# Conversion complete: ortho_1_14.tif -> ortho_1_14.jpg
# Conversion complete: ortho_22_15.tif -> ortho_22_15.jpg
# Conversion complete: ortho_13_6.tif -> ortho_13_6.jpg
# Conversion complete: ortho_16_0.tif -> ortho_16_0.jpg
# Conversion complete: ortho_5_14.tif -> ortho_5_14.jpg
# Conversion complete: ortho_25_20.tif -> ortho_25_20.jpg
# Conversion complete: ortho_2_7.tif -> ortho_2_7.jpg
# Conversion complete: ortho_21_17.tif -> ortho_21_17.jpg
# Conversion complete: ortho_13_0.tif -> ortho_13_0.jpg
# Conversion complete: ortho_9_19.tif -> ortho_9_19.jpg
# Conversion complete: ortho_20_12.tif -> ortho_20_12.jpg
# Conversion complete: ortho_5_20.tif -> ortho_5_20.jpg
# Conversion complete: ortho_15_12.tif -> ortho_15_12.jpg
# Conversion complete: ortho_21_18.tif -> ortho_21_18.jpg
# Conversion complete: ortho_24_18.tif -> ortho_24_18.jpg
# Conversion complete: ortho_7_1.tif -> ortho_7_1.jpg
# Conversion complete: ortho_19_7.tif -> ortho_19_7.jpg
# Conversion complete: ortho_12_18.tif -> ortho_12_18.jpg
# Conversion complete: ortho_26_7.tif -> ortho_26_7.jpg
# Conversion complete: ortho_24_9.tif -> ortho_24_9.jpg
# Conversion complete: ortho_12_8.tif -> ortho_12_8.jpg
# Conversion complete: ortho_2_1.tif -> ortho_2_1.jpg
# Conversion complete: ortho_26_9.tif -> ortho_26_9.jpg
# Conversion complete: ortho_12_3.tif -> ortho_12_3.jpg
# Conversion complete: ortho_9_15.tif -> ortho_9_15.jpg
# Conversion complete: ortho_5_16.tif -> ortho_5_16.jpg
# Conversion complete: ortho_22_9.tif -> ortho_22_9.jpg
# Conversion complete: ortho_7_3.tif -> ortho_7_3.jpg
# Conversion complete: ortho_23_17.tif -> ortho_23_17.jpg
# Conversion complete: ortho_7_18.tif -> ortho_7_18.jpg
# Conversion complete: ortho_1_0.tif -> ortho_1_0.jpg
# Conversion complete: ortho_14_5.tif -> ortho_14_5.jpg
# Conversion complete: ortho_14_2.tif -> ortho_14_2.jpg
# Conversion complete: ortho_15_6.tif -> ortho_15_6.jpg
# Conversion complete: ortho_24_23.tif -> ortho_24_23.jpg
# Conversion complete: ortho_22_14.tif -> ortho_22_14.jpg
# Conversion complete: ortho_15_9.tif -> ortho_15_9.jpg
# Conversion complete: ortho_3_2.tif -> ortho_3_2.jpg
# Conversion complete: ortho_6_11.tif -> ortho_6_11.jpg
# Conversion complete: ortho_5_22.tif -> ortho_5_22.jpg
# Conversion complete: ortho_12_11.tif -> ortho_12_11.jpg
# Conversion complete: ortho_6_10.tif -> ortho_6_10.jpg
# Conversion complete: ortho_22_4.tif -> ortho_22_4.jpg
# Conversion complete: ortho_10_10.tif -> ortho_10_10.jpg
# Conversion complete: ortho_18_5.tif -> ortho_18_5.jpg
# Conversion complete: ortho_24_13.tif -> ortho_24_13.jpg
# Conversion complete: ortho_23_15.tif -> ortho_23_15.jpg
# Conversion complete: ortho_23_1.tif -> ortho_23_1.jpg
# Conversion complete: ortho_6_6.tif -> ortho_6_6.jpg
# Conversion complete: ortho_17_17.tif -> ortho_17_17.jpg
# Conversion complete: ortho_6_21.tif -> ortho_6_21.jpg
# Conversion complete: ortho_6_19.tif -> ortho_6_19.jpg
# Conversion complete: ortho_13_19.tif -> ortho_13_19.jpg
# Conversion complete: ortho_13_23.tif -> ortho_13_23.jpg
# Conversion complete: ortho_23_2.tif -> ortho_23_2.jpg
# Conversion complete: ortho_26_3.tif -> ortho_26_3.jpg
# Conversion complete: ortho_13_16.tif -> ortho_13_16.jpg
# Conversion complete: ortho_3_5.tif -> ortho_3_5.jpg
# Conversion complete: ortho_12_14.tif -> ortho_12_14.jpg
# Conversion complete: ortho_11_16.tif -> ortho_11_16.jpg
# Conversion complete: ortho_5_0.tif -> ortho_5_0.jpg
# Conversion complete: ortho_6_7.tif -> ortho_6_7.jpg
# Conversion complete: ortho_11_1.tif -> ortho_11_1.jpg
# Conversion complete: ortho_11_23.tif -> ortho_11_23.jpg
# Conversion complete: ortho_15_23.tif -> ortho_15_23.jpg
# Conversion complete: ortho_22_3.tif -> ortho_22_3.jpg
# Conversion complete: ortho_23_13.tif -> ortho_23_13.jpg
# Conversion complete: ortho_0_20.tif -> ortho_0_20.jpg
# Conversion complete: ortho_16_9.tif -> ortho_16_9.jpg
# Conversion complete: ortho_18_9.tif -> ortho_18_9.jpg
# Conversion complete: ortho_13_3.tif -> ortho_13_3.jpg
# Conversion complete: ortho_26_21.tif -> ortho_26_21.jpg
# Conversion complete: ortho_19_20.tif -> ortho_19_20.jpg
# Conversion complete: ortho_17_6.tif -> ortho_17_6.jpg
# Conversion complete: ortho_14_15.tif -> ortho_14_15.jpg
# Conversion complete: ortho_19_11.tif -> ortho_19_11.jpg
# Conversion complete: ortho_12_7.tif -> ortho_12_7.jpg
# Conversion complete: ortho_20_7.tif -> ortho_20_7.jpg
# Conversion complete: ortho_9_13.tif -> ortho_9_13.jpg
# Conversion complete: ortho_22_5.tif -> ortho_22_5.jpg
# Conversion complete: ortho_11_21.tif -> ortho_11_21.jpg
# Conversion complete: ortho_17_8.tif -> ortho_17_8.jpg
# Conversion complete: ortho_14_20.tif -> ortho_14_20.jpg
# Conversion complete: ortho_14_21.tif -> ortho_14_21.jpg
# Conversion complete: ortho_10_23.tif -> ortho_10_23.jpg
# Conversion complete: ortho_0_12.tif -> ortho_0_12.jpg
# Conversion complete: ortho_3_17.tif -> ortho_3_17.jpg
# Conversion complete: ortho_4_13.tif -> ortho_4_13.jpg
# Conversion complete: ortho_17_12.tif -> ortho_17_12.jpg
# Conversion complete: ortho_14_10.tif -> ortho_14_10.jpg
# Conversion complete: ortho_19_18.tif -> ortho_19_18.jpg
# Conversion complete: ortho_12_21.tif -> ortho_12_21.jpg
# Conversion complete: ortho_10_22.tif -> ortho_10_22.jpg
# Conversion complete: ortho_14_1.tif -> ortho_14_1.jpg
# Conversion complete: ortho_10_15.tif -> ortho_10_15.jpg
# Conversion complete: ortho_16_5.tif -> ortho_16_5.jpg
# Conversion complete: ortho_2_16.tif -> ortho_2_16.jpg
# Conversion complete: ortho_3_19.tif -> ortho_3_19.jpg
# Conversion complete: ortho_25_8.tif -> ortho_25_8.jpg
# Conversion complete: ortho_0_5.tif -> ortho_0_5.jpg
# Conversion complete: ortho_15_0.tif -> ortho_15_0.jpg
# Conversion complete: ortho_6_8.tif -> ortho_6_8.jpg
# Conversion complete: ortho_0_18.tif -> ortho_0_18.jpg
# Conversion complete: ortho_22_11.tif -> ortho_22_11.jpg
# Conversion complete: ortho_9_0.tif -> ortho_9_0.jpg
# Conversion complete: ortho_15_7.tif -> ortho_15_7.jpg
# Conversion complete: ortho_12_15.tif -> ortho_12_15.jpg
# Conversion complete: ortho_14_6.tif -> ortho_14_6.jpg
# Conversion complete: ortho_6_4.tif -> ortho_6_4.jpg
# Conversion complete: ortho_26_5.tif -> ortho_26_5.jpg
# Conversion complete: ortho_23_18.tif -> ortho_23_18.jpg
# Conversion complete: ortho_23_23.tif -> ortho_23_23.jpg
# Conversion complete: ortho_21_4.tif -> ortho_21_4.jpg
# Conversion complete: ortho_7_0.tif -> ortho_7_0.jpg
# Conversion complete: ortho_5_9.tif -> ortho_5_9.jpg
# Conversion complete: ortho_13_20.tif -> ortho_13_20.jpg
# Conversion complete: ortho_1_3.tif -> ortho_1_3.jpg
# Conversion complete: ortho_25_5.tif -> ortho_25_5.jpg
# Conversion complete: ortho_22_16.tif -> ortho_22_16.jpg
# Conversion complete: ortho_24_20.tif -> ortho_24_20.jpg
# Conversion complete: ortho_21_20.tif -> ortho_21_20.jpg
# Conversion complete: ortho_6_17.tif -> ortho_6_17.jpg
# Conversion complete: ortho_25_2.tif -> ortho_25_2.jpg
# Conversion complete: ortho_0_7.tif -> ortho_0_7.jpg
# Conversion complete: ortho_3_9.tif -> ortho_3_9.jpg
# Conversion complete: ortho_25_15.tif -> ortho_25_15.jpg
# Conversion complete: ortho_8_10.tif -> ortho_8_10.jpg
# Conversion complete: ortho_3_20.tif -> ortho_3_20.jpg
# Conversion complete: ortho_15_19.tif -> ortho_15_19.jpg
# Conversion complete: ortho_18_6.tif -> ortho_18_6.jpg
# Conversion complete: ortho_14_18.tif -> ortho_14_18.jpg
# Conversion complete: ortho_2_13.tif -> ortho_2_13.jpg
# Conversion complete: ortho_3_4.tif -> ortho_3_4.jpg
# Conversion complete: ortho_5_1.tif -> ortho_5_1.jpg
# Conversion complete: ortho_2_9.tif -> ortho_2_9.jpg
# Conversion complete: ortho_2_6.tif -> ortho_2_6.jpg
# Conversion complete: ortho_14_14.tif -> ortho_14_14.jpg
# Conversion complete: ortho_9_1.tif -> ortho_9_1.jpg
# Conversion complete: ortho_8_7.tif -> ortho_8_7.jpg
# Conversion complete: ortho_25_9.tif -> ortho_25_9.jpg
# Conversion complete: ortho_22_10.tif -> ortho_22_10.jpg
# Conversion complete: ortho_13_12.tif -> ortho_13_12.jpg
# Conversion complete: ortho_3_13.tif -> ortho_3_13.jpg
# Conversion complete: ortho_15_5.tif -> ortho_15_5.jpg
# Conversion complete: ortho_5_12.tif -> ortho_5_12.jpg
# Conversion complete: ortho_3_11.tif -> ortho_3_11.jpg
# Conversion complete: ortho_19_4.tif -> ortho_19_4.jpg
# Conversion complete: ortho_11_14.tif -> ortho_11_14.jpg
# Conversion complete: ortho_18_17.tif -> ortho_18_17.jpg
# Conversion complete: ortho_20_9.tif -> ortho_20_9.jpg
# Conversion complete: ortho_23_14.tif -> ortho_23_14.jpg
# Conversion complete: ortho_6_2.tif -> ortho_6_2.jpg
# Conversion complete: ortho_1_7.tif -> ortho_1_7.jpg
# Conversion complete: ortho_20_4.tif -> ortho_20_4.jpg
# Conversion complete: ortho_9_3.tif -> ortho_9_3.jpg
# Conversion complete: ortho_2_17.tif -> ortho_2_17.jpg
# Conversion complete: ortho_17_5.tif -> ortho_17_5.jpg
# Conversion complete: ortho_13_14.tif -> ortho_13_14.jpg
# Conversion complete: ortho_26_23.tif -> ortho_26_23.jpg
# Conversion complete: ortho_19_21.tif -> ortho_19_21.jpg
# Conversion complete: ortho_15_17.tif -> ortho_15_17.jpg
# Conversion complete: ortho_8_9.tif -> ortho_8_9.jpg
# Conversion complete: ortho_21_2.tif -> ortho_21_2.jpg
# Conversion complete: ortho_6_3.tif -> ortho_6_3.jpg
# Conversion complete: ortho_11_17.tif -> ortho_11_17.jpg
# Conversion complete: ortho_13_10.tif -> ortho_13_10.jpg
# Conversion complete: ortho_23_20.tif -> ortho_23_20.jpg
# Conversion complete: ortho_15_4.tif -> ortho_15_4.jpg
# Conversion complete: ortho_24_10.tif -> ortho_24_10.jpg
# Conversion complete: ortho_0_6.tif -> ortho_0_6.jpg
# Conversion complete: ortho_3_7.tif -> ortho_3_7.jpg
# Conversion complete: ortho_10_9.tif -> ortho_10_9.jpg
# Conversion complete: ortho_1_9.tif -> ortho_1_9.jpg
# Conversion complete: ortho_20_18.tif -> ortho_20_18.jpg
# Conversion complete: ortho_16_7.tif -> ortho_16_7.jpg
# Conversion complete: ortho_17_23.tif -> ortho_17_23.jpg
# Conversion complete: ortho_1_6.tif -> ortho_1_6.jpg
# Conversion complete: ortho_4_17.tif -> ortho_4_17.jpg
# Conversion complete: ortho_12_22.tif -> ortho_12_22.jpg
# Conversion complete: ortho_9_10.tif -> ortho_9_10.jpg
# Conversion complete: ortho_12_1.tif -> ortho_12_1.jpg
# Conversion complete: ortho_15_21.tif -> ortho_15_21.jpg
# Conversion complete: ortho_26_16.tif -> ortho_26_16.jpg
# Conversion complete: ortho_14_12.tif -> ortho_14_12.jpg
# Conversion complete: ortho_6_12.tif -> ortho_6_12.jpg
# Conversion complete: ortho_11_20.tif -> ortho_11_20.jpg
# Conversion complete: ortho_9_20.tif -> ortho_9_20.jpg
# Conversion complete: ortho_3_21.tif -> ortho_3_21.jpg
# Conversion complete: ortho_23_9.tif -> ortho_23_9.jpg
# Conversion complete: ortho_1_17.tif -> ortho_1_17.jpg
# Conversion complete: ortho_9_14.tif -> ortho_9_14.jpg
# Conversion complete: ortho_20_16.tif -> ortho_20_16.jpg
# Conversion complete: ortho_10_17.tif -> ortho_10_17.jpg
# Conversion complete: ortho_21_8.tif -> ortho_21_8.jpg
# Conversion complete: ortho_18_13.tif -> ortho_18_13.jpg
# Conversion complete: ortho_1_2.tif -> ortho_1_2.jpg
# Conversion complete: ortho_25_1.tif -> ortho_25_1.jpg
# Conversion complete: ortho_4_21.tif -> ortho_4_21.jpg
# Conversion complete: ortho_24_1.tif -> ortho_24_1.jpg
# Conversion complete: ortho_26_20.tif -> ortho_26_20.jpg
# Conversion complete: ortho_25_16.tif -> ortho_25_16.jpg
# Conversion complete: ortho_26_8.tif -> ortho_26_8.jpg
# Conversion complete: ortho_17_9.tif -> ortho_17_9.jpg
# Conversion complete: ortho_5_15.tif -> ortho_5_15.jpg
# Conversion complete: ortho_20_19.tif -> ortho_20_19.jpg
# Conversion complete: ortho_12_6.tif -> ortho_12_6.jpg
# Conversion complete: ortho_23_7.tif -> ortho_23_7.jpg
# Conversion complete: ortho_17_15.tif -> ortho_17_15.jpg
# Conversion complete: ortho_9_18.tif -> ortho_9_18.jpg
# Conversion complete: ortho_10_16.tif -> ortho_10_16.jpg
# Conversion complete: ortho_10_19.tif -> ortho_10_19.jpg
# Conversion complete: ortho_24_0.tif -> ortho_24_0.jpg
# Conversion complete: ortho_9_16.tif -> ortho_9_16.jpg
# Conversion complete: ortho_8_17.tif -> ortho_8_17.jpg
# Conversion complete: ortho_2_21.tif -> ortho_2_21.jpg
# Conversion complete: ortho_21_11.tif -> ortho_21_11.jpg
# Conversion complete: ortho_18_3.tif -> ortho_18_3.jpg
# Conversion complete: ortho_22_0.tif -> ortho_22_0.jpg
# Conversion complete: ortho_4_20.tif -> ortho_4_20.jpg
# Conversion complete: ortho_8_8.tif -> ortho_8_8.jpg
# Conversion complete: ortho_19_15.tif -> ortho_19_15.jpg
# Conversion complete: ortho_17_22.tif -> ortho_17_22.jpg
# Conversion complete: ortho_1_15.tif -> ortho_1_15.jpg
# Conversion complete: ortho_4_3.tif -> ortho_4_3.jpg
# Conversion complete: ortho_24_11.tif -> ortho_24_11.jpg
# Conversion complete: ortho_1_22.tif -> ortho_1_22.jpg
# Conversion complete: ortho_15_15.tif -> ortho_15_15.jpg
# Conversion complete: ortho_26_1.tif -> ortho_26_1.jpg
# Conversion complete: ortho_20_13.tif -> ortho_20_13.jpg
# Conversion complete: ortho_17_13.tif -> ortho_17_13.jpg
# Conversion complete: ortho_7_22.tif -> ortho_7_22.jpg
# Conversion complete: ortho_0_3.tif -> ortho_0_3.jpg
# Conversion complete: ortho_13_22.tif -> ortho_13_22.jpg
# Conversion complete: ortho_9_22.tif -> ortho_9_22.jpg
# Conversion complete: ortho_0_8.tif -> ortho_0_8.jpg
# Conversion complete: ortho_22_7.tif -> ortho_22_7.jpg
# Conversion complete: ortho_25_14.tif -> ortho_25_14.jpg
# Conversion complete: ortho_10_11.tif -> ortho_10_11.jpg
# Conversion complete: ortho_16_16.tif -> ortho_16_16.jpg
# Conversion complete: ortho_18_22.tif -> ortho_18_22.jpg
# Conversion complete: ortho_10_8.tif -> ortho_10_8.jpg
# Conversion complete: ortho_26_6.tif -> ortho_26_6.jpg
# Conversion complete: ortho_21_3.tif -> ortho_21_3.jpg
# Conversion complete: ortho_17_1.tif -> ortho_17_1.jpg
# Conversion complete: ortho_14_17.tif -> ortho_14_17.jpg
# Conversion complete: ortho_8_11.tif -> ortho_8_11.jpg
# Conversion complete: ortho_6_22.tif -> ortho_6_22.jpg
# Conversion complete: ortho_12_17.tif -> ortho_12_17.jpg
# Conversion complete: ortho_12_4.tif -> ortho_12_4.jpg
# Conversion complete: ortho_16_13.tif -> ortho_16_13.jpg
# Conversion complete: ortho_19_9.tif -> ortho_19_9.jpg
# Conversion complete: ortho_20_1.tif -> ortho_20_1.jpg
# Conversion complete: ortho_20_14.tif -> ortho_20_14.jpg
# Conversion complete: ortho_7_7.tif -> ortho_7_7.jpg
# Conversion complete: ortho_6_18.tif -> ortho_6_18.jpg
# Conversion complete: ortho_4_2.tif -> ortho_4_2.jpg
# Conversion complete: ortho_8_6.tif -> ortho_8_6.jpg
# Conversion complete: ortho_11_8.tif -> ortho_11_8.jpg
# Conversion complete: ortho_0_21.tif -> ortho_0_21.jpg
# Conversion complete: ortho_20_23.tif -> ortho_20_23.jpg
# Conversion complete: ortho_7_10.tif -> ortho_7_10.jpg
# Conversion complete: ortho_16_12.tif -> ortho_16_12.jpg
# Conversion complete: ortho_10_2.tif -> ortho_10_2.jpg
# Conversion complete: ortho_2_14.tif -> ortho_2_14.jpg
# Conversion complete: ortho_20_17.tif -> ortho_20_17.jpg
# Conversion complete: ortho_25_17.tif -> ortho_25_17.jpg
# Conversion complete: ortho_17_10.tif -> ortho_17_10.jpg
# Conversion complete: ortho_12_16.tif -> ortho_12_16.jpg
# Conversion complete: ortho_1_11.tif -> ortho_1_11.jpg
# Conversion complete: ortho_11_3.tif -> ortho_11_3.jpg
# Conversion complete: ortho_17_19.tif -> ortho_17_19.jpg
# Conversion complete: ortho_10_5.tif -> ortho_10_5.jpg
# Conversion complete: ortho_15_11.tif -> ortho_15_11.jpg
# Conversion complete: ortho_5_3.tif -> ortho_5_3.jpg
# Conversion complete: ortho_19_22.tif -> ortho_19_22.jpg
# Conversion complete: ortho_7_19.tif -> ortho_7_19.jpg
# Conversion complete: ortho_23_0.tif -> ortho_23_0.jpg
# Conversion complete: ortho_4_0.tif -> ortho_4_0.jpg
# Conversion complete: ortho_4_12.tif -> ortho_4_12.jpg
# Conversion complete: ortho_23_16.tif -> ortho_23_16.jpg
# Conversion complete: ortho_0_14.tif -> ortho_0_14.jpg
# Conversion complete: ortho_13_21.tif -> ortho_13_21.jpg
# Conversion complete: ortho_13_2.tif -> ortho_13_2.jpg
# Conversion complete: ortho_2_4.tif -> ortho_2_4.jpg
# Conversion complete: ortho_9_12.tif -> ortho_9_12.jpg
# Conversion complete: ortho_4_16.tif -> ortho_4_16.jpg
# Conversion complete: ortho_11_10.tif -> ortho_11_10.jpg
# Conversion complete: ortho_6_0.tif -> ortho_6_0.jpg
# Conversion complete: ortho_25_21.tif -> ortho_25_21.jpg
# Conversion complete: ortho_20_5.tif -> ortho_20_5.jpg
# Conversion complete: ortho_6_14.tif -> ortho_6_14.jpg
# Conversion complete: ortho_18_10.tif -> ortho_18_10.jpg
# Conversion complete: ortho_22_22.tif -> ortho_22_22.jpg
# Conversion complete: ortho_17_14.tif -> ortho_17_14.jpg
# Conversion complete: ortho_2_3.tif -> ortho_2_3.jpg
# Conversion complete: ortho_7_9.tif -> ortho_7_9.jpg
# Conversion complete: ortho_11_4.tif -> ortho_11_4.jpg
# Conversion complete: ortho_14_13.tif -> ortho_14_13.jpg
# Conversion complete: ortho_15_13.tif -> ortho_15_13.jpg
# Conversion complete: ortho_5_17.tif -> ortho_5_17.jpg
# Conversion complete: ortho_21_15.tif -> ortho_21_15.jpg
# Conversion complete: ortho_9_4.tif -> ortho_9_4.jpg
# Conversion complete: ortho_4_4.tif -> ortho_4_4.jpg
# Conversion complete: ortho_12_13.tif -> ortho_12_13.jpg
# Conversion complete: ortho_4_8.tif -> ortho_4_8.jpg
# Conversion complete: ortho_14_23.tif -> ortho_14_23.jpg
# Conversion complete: ortho_24_3.tif -> ortho_24_3.jpg
# Conversion complete: ortho_16_14.tif -> ortho_16_14.jpg
# Conversion complete: ortho_15_10.tif -> ortho_15_10.jpg
# Conversion complete: ortho_2_8.tif -> ortho_2_8.jpg
# Conversion complete: ortho_4_10.tif -> ortho_4_10.jpg
# Conversion complete: ortho_18_12.tif -> ortho_18_12.jpg
# Conversion complete: ortho_14_0.tif -> ortho_14_0.jpg
# Conversion complete: ortho_6_9.tif -> ortho_6_9.jpg
# Conversion complete: ortho_12_0.tif -> ortho_12_0.jpg
# Conversion complete: ortho_24_2.tif -> ortho_24_2.jpg
# Conversion complete: ortho_25_18.tif -> ortho_25_18.jpg
# Conversion complete: ortho_3_0.tif -> ortho_3_0.jpg
# Conversion complete: ortho_20_2.tif -> ortho_20_2.jpg
# Conversion complete: ortho_12_10.tif -> ortho_12_10.jpg
# Conversion complete: ortho_9_8.tif -> ortho_9_8.jpg
# Conversion complete: ortho_1_8.tif -> ortho_1_8.jpg
# Conversion complete: ortho_25_10.tif -> ortho_25_10.jpg
# Conversion complete: ortho_26_22.tif -> ortho_26_22.jpg
# Conversion complete: ortho_20_15.tif -> ortho_20_15.jpg
# Conversion complete: ortho_26_11.tif -> ortho_26_11.jpg
# Conversion complete: ortho_1_18.tif -> ortho_1_18.jpg
# Conversion complete: ortho_18_14.tif -> ortho_18_14.jpg
# Conversion complete: ortho_21_5.tif -> ortho_21_5.jpg
# Conversion complete: ortho_15_22.tif -> ortho_15_22.jpg
# Conversion complete: ortho_4_23.tif -> ortho_4_23.jpg
# Conversion complete: ortho_8_21.tif -> ortho_8_21.jpg
# Conversion complete: ortho_21_14.tif -> ortho_21_14.jpg
# Conversion complete: ortho_16_17.tif -> ortho_16_17.jpg
# Conversion complete: ortho_9_7.tif -> ortho_9_7.jpg
# Conversion complete: ortho_13_5.tif -> ortho_13_5.jpg
# Conversion complete: ortho_22_12.tif -> ortho_22_12.jpg
# Conversion complete: ortho_9_6.tif -> ortho_9_6.jpg
# Conversion complete: ortho_25_3.tif -> ortho_25_3.jpg
# Conversion complete: ortho_4_22.tif -> ortho_4_22.jpg
# Conversion complete: ortho_20_10.tif -> ortho_20_10.jpg
# Conversion complete: ortho_14_16.tif -> ortho_14_16.jpg
# Conversion complete: ortho_23_4.tif -> ortho_23_4.jpg
# Conversion complete: ortho_10_12.tif -> ortho_10_12.jpg
# Conversion complete: ortho_8_1.tif -> ortho_8_1.jpg
# Conversion complete: ortho_18_2.tif -> ortho_18_2.jpg
# Conversion complete: ortho_10_13.tif -> ortho_10_13.jpg
# Conversion complete: ortho_25_22.tif -> ortho_25_22.jpg
# Conversion complete: ortho_26_4.tif -> ortho_26_4.jpg
# Conversion complete: ortho_6_23.tif -> ortho_6_23.jpg
# Conversion complete: ortho_25_23.tif -> ortho_25_23.jpg
# Conversion complete: ortho_26_19.tif -> ortho_26_19.jpg
# Conversion complete: ortho_21_23.tif -> ortho_21_23.jpg
# Conversion complete: ortho_5_7.tif -> ortho_5_7.jpg
# Conversion complete: ortho_5_8.tif -> ortho_5_8.jpg
# Conversion complete: ortho_16_23.tif -> ortho_16_23.jpg
# Conversion complete: ortho_11_0.tif -> ortho_11_0.jpg
# Conversion complete: ortho_5_19.tif -> ortho_5_19.jpg
# Conversion complete: ortho_19_2.tif -> ortho_19_2.jpg
# Conversion complete: ortho_1_19.tif -> ortho_1_19.jpg
# Conversion complete: ortho_13_15.tif -> ortho_13_15.jpg
# Conversion complete: ortho_25_19.tif -> ortho_25_19.jpg
# Conversion complete: ortho_19_0.tif -> ortho_19_0.jpg
# Conversion complete: ortho_21_19.tif -> ortho_21_19.jpg
# Conversion complete: ortho_3_15.tif -> ortho_3_15.jpg
# Conversion complete: ortho_0_10.tif -> ortho_0_10.jpg
# Conversion complete: ortho_13_4.tif -> ortho_13_4.jpg
# Conversion complete: ortho_23_6.tif -> ortho_23_6.jpg
# Conversion complete: ortho_0_22.tif -> ortho_0_22.jpg
# Conversion complete: ortho_11_11.tif -> ortho_11_11.jpg
# Conversion complete: ortho_11_22.tif -> ortho_11_22.jpg
# Conversion complete: ortho_3_1.tif -> ortho_3_1.jpg
# Conversion complete: ortho_24_6.tif -> ortho_24_6.jpg
# Conversion complete: ortho_7_13.tif -> ortho_7_13.jpg
# Conversion complete: ortho_12_20.tif -> ortho_12_20.jpg
# Conversion complete: ortho_17_20.tif -> ortho_17_20.jpg
# Conversion complete: ortho_1_5.tif -> ortho_1_5.jpg
# Conversion complete: ortho_5_13.tif -> ortho_5_13.jpg
# Conversion complete: ortho_0_16.tif -> ortho_0_16.jpg
# Conversion complete: ortho_8_2.tif -> ortho_8_2.jpg
# Conversion complete: ortho_13_17.tif -> ortho_13_17.jpg
# Conversion complete: ortho_1_12.tif -> ortho_1_12.jpg
# Conversion complete: ortho_6_16.tif -> ortho_6_16.jpg
# Conversion complete: ortho_11_5.tif -> ortho_11_5.jpg
# Conversion complete: ortho_14_19.tif -> ortho_14_19.jpg
# Conversion complete: ortho_5_23.tif -> ortho_5_23.jpg
# Conversion complete: ortho_1_16.tif -> ortho_1_16.jpg
# Conversion complete: ortho_18_7.tif -> ortho_18_7.jpg
# Conversion complete: ortho_26_18.tif -> ortho_26_18.jpg
# Conversion complete: ortho_13_9.tif -> ortho_13_9.jpg
# Conversion complete: ortho_11_18.tif -> ortho_11_18.jpg
# Conversion complete: ortho_3_14.tif -> ortho_3_14.jpg
# Conversion complete: ortho_20_20.tif -> ortho_20_20.jpg
# Conversion complete: ortho_11_2.tif -> ortho_11_2.jpg
# Conversion complete: ortho_4_5.tif -> ortho_4_5.jpg
# Conversion complete: ortho_14_4.tif -> ortho_14_4.jpg
# Conversion complete: ortho_24_17.tif -> ortho_24_17.jpg
# Conversion complete: ortho_18_0.tif -> ortho_18_0.jpg
# Conversion complete: ortho_18_4.tif -> ortho_18_4.jpg
# Conversion complete: ortho_19_3.tif -> ortho_19_3.jpg
# Conversion complete: ortho_24_19.tif -> ortho_24_19.jpg
# Conversion complete: ortho_4_6.tif -> ortho_4_6.jpg
# Conversion complete: ortho_23_12.tif -> ortho_23_12.jpg
# Conversion complete: ortho_18_20.tif -> ortho_18_20.jpg
# Conversion complete: ortho_16_6.tif -> ortho_16_6.jpg
# Conversion complete: ortho_3_3.tif -> ortho_3_3.jpg
# Conversion complete: ortho_26_17.tif -> ortho_26_17.jpg
# Conversion complete: ortho_13_13.tif -> ortho_13_13.jpg
# Conversion complete: ortho_16_15.tif -> ortho_16_15.jpg
# Conversion complete: ortho_7_20.tif -> ortho_7_20.jpg
# Conversion complete: ortho_19_16.tif -> ortho_19_16.jpg
# Conversion complete: ortho_17_0.tif -> ortho_17_0.jpg
# Conversion complete: ortho_14_11.tif -> ortho_14_11.jpg
# Conversion complete: ortho_0_15.tif -> ortho_0_15.jpg
# Conversion complete: ortho_17_18.tif -> ortho_17_18.jpg
# Conversion complete: ortho_22_19.tif -> ortho_22_19.jpg
# Conversion complete: ortho_22_1.tif -> ortho_22_1.jpg
# Conversion complete: ortho_6_15.tif -> ortho_6_15.jpg
# Conversion complete: ortho_4_7.tif -> ortho_4_7.jpg
# Conversion complete: ortho_13_11.tif -> ortho_13_11.jpg
# Conversion complete: ortho_26_13.tif -> ortho_26_13.jpg
# Conversion complete: ortho_20_11.tif -> ortho_20_11.jpg
# Conversion complete: ortho_8_13.tif -> ortho_8_13.jpg
# Conversion complete: ortho_3_18.tif -> ortho_3_18.jpg
# Conversion complete: ortho_21_9.tif -> ortho_21_9.jpg
# Conversion complete: ortho_14_9.tif -> ortho_14_9.jpg
# Conversion complete: ortho_5_5.tif -> ortho_5_5.jpg
# Conversion complete: ortho_16_19.tif -> ortho_16_19.jpg
# Conversion complete: ortho_19_10.tif -> ortho_19_10.jpg
# Conversion complete: ortho_20_8.tif -> ortho_20_8.jpg
# Conversion complete: ortho_7_5.tif -> ortho_7_5.jpg
# Conversion complete: ortho_25_4.tif -> ortho_25_4.jpg
# Conversion complete: ortho_2_2.tif -> ortho_2_2.jpg
# Conversion complete: ortho_21_22.tif -> ortho_21_22.jpg
# Conversion complete: ortho_4_11.tif -> ortho_4_11.jpg
# Conversion complete: ortho_20_22.tif -> ortho_20_22.jpg
# Conversion complete: ortho_17_16.tif -> ortho_17_16.jpg
# Conversion complete: ortho_16_1.tif -> ortho_16_1.jpg
# Conversion complete: ortho_10_0.tif -> ortho_10_0.jpg
# Conversion complete: ortho_10_3.tif -> ortho_10_3.jpg
# Conversion complete: ortho_17_4.tif -> ortho_17_4.jpg
# Conversion complete: ortho_12_23.tif -> ortho_12_23.jpg
# Conversion complete: ortho_2_20.tif -> ortho_2_20.jpg
# Conversion complete: ortho_9_11.tif -> ortho_9_11.jpg
# Conversion complete: ortho_7_6.tif -> ortho_7_6.jpg
# Conversion complete: ortho_3_23.tif -> ortho_3_23.jpg
# Conversion complete: ortho_25_12.tif -> ortho_25_12.jpg
# Conversion complete: ortho_10_7.tif -> ortho_10_7.jpg
# Conversion complete: ortho_23_22.tif -> ortho_23_22.jpg
# Conversion complete: ortho_1_10.tif -> ortho_1_10.jpg
# Conversion complete: ortho_22_18.tif -> ortho_22_18.jpg
# Conversion complete: ortho_2_5.tif -> ortho_2_5.jpg
# Conversion complete: ortho_26_12.tif -> ortho_26_12.jpg
# Conversion complete: ortho_21_13.tif -> ortho_21_13.jpg
# Conversion complete: ortho_10_21.tif -> ortho_10_21.jpg
# Conversion complete: ortho_22_17.tif -> ortho_22_17.jpg
# Conversion complete: ortho_12_9.tif -> ortho_12_9.jpg
# Conversion complete: ortho_1_21.tif -> ortho_1_21.jpg
# Conversion complete: ortho_8_18.tif -> ortho_8_18.jpg
# Conversion complete: ortho_22_23.tif -> ortho_22_23.jpg
# Conversion complete: ortho_14_8.tif -> ortho_14_8.jpg
# Conversion complete: ortho_12_5.tif -> ortho_12_5.jpg
# Conversion complete: ortho_23_8.tif -> ortho_23_8.jpg
# Conversion complete: ortho_25_13.tif -> ortho_25_13.jpg
# Conversion complete: ortho_23_5.tif -> ortho_23_5.jpg
# Conversion complete: ortho_21_21.tif -> ortho_21_21.jpg
# Conversion complete: ortho_9_21.tif -> ortho_9_21.jpg
# Conversion complete: ortho_5_10.tif -> ortho_5_10.jpg
# Conversion complete: ortho_26_15.tif -> ortho_26_15.jpg
# Conversion complete: ortho_8_12.tif -> ortho_8_12.jpg
# Conversion complete: ortho_11_6.tif -> ortho_11_6.jpg
# Conversion complete: ortho_8_4.tif -> ortho_8_4.jpg
# Conversion complete: ortho_19_23.tif -> ortho_19_23.jpg
# Conversion complete: ortho_2_23.tif -> ortho_2_23.jpg
# Conversion complete: ortho_21_6.tif -> ortho_21_6.jpg
# Conversion complete: ortho_19_13.tif -> ortho_19_13.jpg
# Conversion complete: ortho_12_19.tif -> ortho_12_19.jpg
# Conversion complete: ortho_26_0.tif -> ortho_26_0.jpg
# Conversion complete: ortho_7_4.tif -> ortho_7_4.jpg
# Conversion complete: ortho_8_3.tif -> ortho_8_3.jpg
# Conversion complete: ortho_11_19.tif -> ortho_11_19.jpg
# Conversion complete: ortho_23_10.tif -> ortho_23_10.jpg
# Conversion complete: ortho_10_14.tif -> ortho_10_14.jpg
# Conversion complete: ortho_24_4.tif -> ortho_24_4.jpg
# Conversion complete: ortho_18_23.tif -> ortho_18_23.jpg
# Conversion complete: ortho_25_6.tif -> ortho_25_6.jpg
# Conversion complete: ortho_6_13.tif -> ortho_6_13.jpg
# Conversion complete: ortho_4_14.tif -> ortho_4_14.jpg
# Conversion complete: ortho_21_12.tif -> ortho_21_12.jpg
# Conversion complete: ortho_16_10.tif -> ortho_16_10.jpg
# Conversion complete: ortho_24_16.tif -> ortho_24_16.jpg
# Conversion complete: ortho_4_9.tif -> ortho_4_9.jpg
# Conversion complete: ortho_17_7.tif -> ortho_17_7.jpg
# Conversion complete: ortho_21_0.tif -> ortho_21_0.jpg
# Conversion complete: ortho_7_17.tif -> ortho_7_17.jpg
# Conversion complete: ortho_3_12.tif -> ortho_3_12.jpg
# Conversion complete: ortho_8_5.tif -> ortho_8_5.jpg
# Conversion complete: ortho_4_1.tif -> ortho_4_1.jpg
# Conversion complete: ortho_21_7.tif -> ortho_21_7.jpg
# Conversion complete: ortho_4_19.tif -> ortho_4_19.jpg
# Conversion complete: ortho_0_11.tif -> ortho_0_11.jpg
# Conversion complete: ortho_20_6.tif -> ortho_20_6.jpg
# Conversion complete: ortho_2_0.tif -> ortho_2_0.jpg
# Conversion complete: ortho_0_4.tif -> ortho_0_4.jpg
# Conversion complete: ortho_5_11.tif -> ortho_5_11.jpg
# Conversion complete: ortho_4_18.tif -> ortho_4_18.jpg
# Conversion complete: ortho_8_14.tif -> ortho_8_14.jpg
# Conversion complete: ortho_11_13.tif -> ortho_11_13.jpg
# Conversion complete: ortho_8_22.tif -> ortho_8_22.jpg
# Conversion complete: ortho_15_2.tif -> ortho_15_2.jpg
# Conversion complete: ortho_24_12.tif -> ortho_24_12.jpg
# Conversion complete: ortho_24_8.tif -> ortho_24_8.jpg
# Conversion complete: ortho_1_20.tif -> ortho_1_20.jpg
# Conversion complete: ortho_18_16.tif -> ortho_18_16.jpg
# Conversion complete: ortho_1_13.tif -> ortho_1_13.jpg
# Conversion complete: ortho_22_2.tif -> ortho_22_2.jpg
# Conversion complete: ortho_0_9.tif -> ortho_0_9.jpg
# Conversion complete: ortho_24_5.tif -> ortho_24_5.jpg
# Conversion complete: ortho_13_1.tif -> ortho_13_1.jpg
# Conversion complete: ortho_0_0.tif -> ortho_0_0.jpg
# Conversion complete: ortho_18_1.tif -> ortho_18_1.jpg
# Conversion complete: ortho_5_2.tif -> ortho_5_2.jpg
# Conversion complete: ortho_6_1.tif -> ortho_6_1.jpg
# Conversion complete: ortho_7_21.tif -> ortho_7_21.jpg
# Conversion complete: ortho_10_6.tif -> ortho_10_6.jpg
# Conversion complete: ortho_1_4.tif -> ortho_1_4.jpg
# Conversion complete: ortho_8_16.tif -> ortho_8_16.jpg
# Conversion complete: ortho_16_8.tif -> ortho_16_8.jpg
# Conversion complete: ortho_18_19.tif -> ortho_18_19.jpg
# Conversion complete: ortho_15_14.tif -> ortho_15_14.jpg
# Conversion complete: ortho_26_10.tif -> ortho_26_10.jpg
# Conversion complete: ortho_10_20.tif -> ortho_10_20.jpg
# Conversion complete: ortho_20_0.tif -> ortho_20_0.jpg
# Conversion complete: ortho_7_12.tif -> ortho_7_12.jpg
# Conversion complete: ortho_7_11.tif -> ortho_7_11.jpg
# Conversion complete: ortho_0_1.tif -> ortho_0_1.jpg
# Conversion complete: ortho_15_16.tif -> ortho_15_16.jpg
# Conversion complete: ortho_22_8.tif -> ortho_22_8.jpg
# Conversion complete: ortho_22_13.tif -> ortho_22_13.jpg
# Conversion complete: ortho_2_18.tif -> ortho_2_18.jpg
# Conversion complete: ortho_17_2.tif -> ortho_17_2.jpg
# Conversion complete: ortho_19_5.tif -> ortho_19_5.jpg
# Conversion complete: ortho_13_8.tif -> ortho_13_8.jpg
# Conversion complete: ortho_20_21.tif -> ortho_20_21.jpg
# Conversion complete: ortho_24_7.tif -> ortho_24_7.jpg
# Conversion complete: ortho_15_20.tif -> ortho_15_20.jpg
# Conversion complete: ortho_9_5.tif -> ortho_9_5.jpg
# Conversion complete: ortho_18_21.tif -> ortho_18_21.jpg
# Conversion complete: ortho_16_2.tif -> ortho_16_2.jpg
# Conversion complete: ortho_23_11.tif -> ortho_23_11.jpg
# Conversion complete: ortho_26_14.tif -> ortho_26_14.jpg
# Conversion complete: ortho_8_20.tif -> ortho_8_20.jpg
# Conversion complete: ortho_14_3.tif -> ortho_14_3.jpg
# Conversion complete: ortho_16_11.tif -> ortho_16_11.jpg
# Conversion complete: ortho_23_21.tif -> ortho_23_21.jpg
# Conversion complete: ortho_19_14.tif -> ortho_19_14.jpg
# Conversion complete: ortho_10_18.tif -> ortho_10_18.jpg
# Conversion complete: ortho_3_16.tif -> ortho_3_16.jpg
# Conversion complete: ortho_8_15.tif -> ortho_8_15.jpg
# Conversion complete: ortho_16_3.tif -> ortho_16_3.jpg
# Conversion complete: ortho_16_4.tif -> ortho_16_4.jpg
# Conversion complete: ortho_13_7.tif -> ortho_13_7.jpg
# Conversion complete: ortho_21_10.tif -> ortho_21_10.jpg
# Conversion complete: ortho_22_21.tif -> ortho_22_21.jpg
# Conversion complete: ortho_0_2.tif -> ortho_0_2.jpg
# Conversion complete: ortho_3_6.tif -> ortho_3_6.jpg
# Conversion complete: ortho_19_17.tif -> ortho_19_17.jpg
# Conversion complete: ortho_1_1.tif -> ortho_1_1.jpg
# Conversion complete: ortho_6_5.tif -> ortho_6_5.jpg
# Conversion complete: ortho_12_2.tif -> ortho_12_2.jpg
# Conversion complete: ortho_15_18.tif -> ortho_15_18.jpg
# Conversion complete: ortho_10_1.tif -> ortho_10_1.jpg
# Conversion complete: ortho_24_15.tif -> ortho_24_15.jpg
# Conversion complete: ortho_7_14.tif -> ortho_7_14.jpg
# Conversion complete: ortho_3_22.tif -> ortho_3_22.jpg
# Conversion complete: ortho_13_18.tif -> ortho_13_18.jpg
# Conversion complete: ortho_3_10.tif -> ortho_3_10.jpg
# Conversion complete: ortho_11_7.tif -> ortho_11_7.jpg
# Conversion complete: ortho_19_8.tif -> ortho_19_8.jpg
# Conversion complete: ortho_20_3.tif -> ortho_20_3.jpg
# Conversion complete: ortho_12_12.tif -> ortho_12_12.jpg
# Conversion complete: ortho_2_22.tif -> ortho_2_22.jpg
# Conversion complete: ortho_18_8.tif -> ortho_18_8.jpg
# Conversion complete: ortho_25_11.tif -> ortho_25_11.jpg
# Conversion complete: ortho_17_3.tif -> ortho_17_3.jpg
# Conversion complete: ortho_19_19.tif -> ortho_19_19.jpg
# Conversion complete: ortho_7_15.tif -> ortho_7_15.jpg
# Conversion complete: ortho_16_18.tif -> ortho_16_18.jpg
# Conversion complete: ortho_18_11.tif -> ortho_18_11.jpg
# Conversion complete: ortho_3_8.tif -> ortho_3_8.jpg
# Conversion complete: ortho_8_19.tif -> ortho_8_19.jpg
# Conversion complete: ortho_7_2.tif -> ortho_7_2.jpg
# Conversion complete: ortho_4_15.tif -> ortho_4_15.jpg
# Conversion complete: ortho_15_8.tif -> ortho_15_8.jpg
# Conversion complete: ortho_23_3.tif -> ortho_23_3.jpg
# Conversion complete: ortho_2_15.tif -> ortho_2_15.jpg
# Conversion complete: ortho_22_6.tif -> ortho_22_6.jpg
# Conversion complete: ortho_16_21.tif -> ortho_16_21.jpg
# Conversion complete: ortho_5_6.tif -> ortho_5_6.jpg
# Conversion complete: ortho_8_0.tif -> ortho_8_0.jpg
# Conversion complete: ortho_15_1.tif -> ortho_15_1.jpg
# Conversion complete: ortho_11_12.tif -> ortho_11_12.jpg
# Conversion complete: ortho_22_20.tif -> ortho_22_20.jpg
# Conversion complete: ortho_7_16.tif -> ortho_7_16.jpg
# Conversion complete: ortho_8_23.tif -> ortho_8_23.jpg
# Conversion complete: ortho_24_22.tif -> ortho_24_22.jpg
# Conversion complete: ortho_17_11.tif -> ortho_17_11.jpg
# Conversion complete: ortho_18_15.tif -> ortho_18_15.jpg
# Conversion complete: ortho_26_2.tif -> ortho_26_2.jpg
# Conversion complete: ortho_9_17.tif -> ortho_9_17.jpg
# Conversion complete: ortho_0_17.tif -> ortho_0_17.jpg
# Conversion complete: ortho_0_19.tif -> ortho_0_19.jpg
# Conversion complete: ortho_25_0.tif -> ortho_25_0.jpg
# Conversion complete: ortho_19_1.tif -> ortho_19_1.jpg
# Conversion complete: ortho_2_11.tif -> ortho_2_11.jpg
# Conversion complete: ortho_5_18.tif -> ortho_5_18.jpg
# Conversion complete: ortho_6_20.tif -> ortho_6_20.jpg
# Conversion complete: ortho_2_19.tif -> ortho_2_19.jpg
# Conversion complete: ortho_14_7.tif -> ortho_14_7.jpg
# Conversion complete: ortho_24_21.tif -> ortho_24_21.jpg
# Conversion complete: ortho_5_4.tif -> ortho_5_4.jpg
# Conversion complete: ortho_21_16.tif -> ortho_21_16.jpg
# Conversion complete: ortho_15_3.tif -> ortho_15_3.jpg
# Conversion complete: ortho_10_4.tif -> ortho_10_4.jpg
# Conversion complete: ortho_9_9.tif -> ortho_9_9.jpg
# Conversion complete: ortho_2_10.tif -> ortho_2_10.jpg
# Conversion complete: ortho_19_6.tif -> ortho_19_6.jpg
# Conversion complete: ortho_9_2.tif -> ortho_9_2.jpg
# Conversion complete: ortho_17_21.tif -> ortho_17_21.jpg
# Conversion complete: ortho_18_18.tif -> ortho_18_18.jpg
# Conversion complete: ortho_11_15.tif -> ortho_11_15.jpg
# Conversion complete: ortho_16_20.tif -> ortho_16_20.jpg
# Conversion complete: ortho_25_7.tif -> ortho_25_7.jpg
